# %%
#importing important libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing class1 dataset
df_cls1 = pd.read_csv(r"C:\Users\sarad\Downloads\Batchwise Attendance Data - Class 1.csv")

# Importing class2 dataset
df_cls2 = pd.read_csv(r"C:\Users\sarad\Downloads\Batchwise Attendance Data - Class 2.csv")

# %%
#To check first 5 rows
df_cls1.head()
# Out:
#    Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21  \
# 0                 1  WORKING   Missed           9   Missed         10
# 1                 2      NaN   Missed           8   Missed          6
# 2                 3  STUDENT   Missed           5   Missed          5
# 3                 4  STUDENT   Missed           6   Missed          6
# 4                 5  WORKING   Missed           6   Missed          7
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ...  05-01-21  R-5-01-21  \
# 0    Missed          8    Missed          5  ...    Missed          8
# 1    Missed          9  Attended          9  ...  Attended          7
# 2    Missed          8    Missed          9  ...  Attended          6
# 3  Attended          8    Missed          6  ...    Missed          6
# 4    Missed          9    Missed          6  ...    Missed          6
#
#    04-01-21  R-4-01-21  03-01-21  R-3-01-21  02-01-21  R-02-01-21  01-01-21  \
# 0    Missed          9    Missed          8    Missed           6    Missed
# 1  Attended          7    Missed          8  Attended           7    Missed
# 2    Missed          6    Missed          8  Attended          10  Attended
# 3  Attended          8  Attended          7  Attended           5  Attended
# 4    Missed         10    Missed         10    Missed           8    Missed
#
#    R-01-01-21
# 0           8
# 1           8
# 2          10
# 3           6
# 4           7
#
# [5 rows x 22 columns]

# %%
#To check column names
df_cls1.columns
# Out:
# Index(['Student Roll Num', 'Type', '10-01-21', 'R-10-01-21', '09-01-21',
#        'R-9-01-21', '08-01-21', 'R-8-01-21', '07-01-21', 'R-7-01-21',
#        '06-01-21', 'R-6-01-21', '05-01-21', 'R-5-01-21', '04-01-21',
#        'R-4-01-21', '03-01-21', 'R-3-01-21', '02-01-21', 'R-02-01-21',
#        '01-01-21', 'R-01-01-21'],
#       dtype='object')

# %%
#To get more info
df_cls1.describe()
# Out:
#        Student Roll Num  R-10-01-21  R-9-01-21  R-8-01-21  R-7-01-21  \
# count         57.000000   57.000000  57.000000  57.000000  57.000000
# mean          29.000000    7.228070   7.192982   7.824561   7.543860
# std           16.598193    1.783031   1.684367   1.513308   1.832935
# min            1.000000    5.000000   5.000000   5.000000   5.000000
# 25%           15.000000    6.000000   6.000000   7.000000   6.000000
# 50%           29.000000    7.000000   7.000000   8.000000   8.000000
# 75%           43.000000    9.000000   8.000000   9.000000   9.000000
# max           57.000000   10.000000  10.000000  10.000000  10.000000
#
#        R-6-01-21  R-5-01-21  R-4-01-21  R-3-01-21  R-02-01-21  R-01-01-21
# count  57.000000  57.000000  57.000000  57.000000   57.000000   57.000000
# mean    7.649123   7.456140   7.684211   7.824561    7.280702    7.561404
# std     1.767678   1.712039   1.691976   1.681016    1.644845    1.679897
# min     5.000000   5.000000   5.000000   5.000000    5.000000    5.000000
# 25%     6.000000   6.000000   6.000000   7.000000    6.000000    6.000000
# 50%     8.000000   7.000000   8.000000   8.000000    7.000000    7.000000
# 75%     9.000000   9.000000   9.000000   9.000000    8.000000    9.000000
# max    10.000000  10.000000  10.000000  10.000000   10.000000   10.000000

# %%
df_cls1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student Roll Num  57 non-null     int64
#  1   Type              32 non-null     object
#  2   10-01-21          57 non-null     object
#  3   R-10-01-21        57 non-null     int64
#  4   09-01-21          57 non-null     object
#  5   R-9-01-21         57 non-null     int64
#  6   08-01-21          57 non-null     object
#  7   R-8-01-21         57 non-null     int64
#  8   07-01-21          56 non-null     object
#  9   R-7-01-21         57 non-null     int64
#  10  06-01-21          56 non-null     object
#  11  R-6-01-21         57 non-null     int64
#  12  05-01-21          56 non-null     object
#  13  R-5-01-21         57 non-null     int64
#  14  04-01-21          56 non-null     object
#  15  R-4-01-21         57 non-null     int64
#  16  03-01-21          56 non-null     object
#  17  R-3-01-21         57 non-null     int64
#  18  02-01-21          56 non-null     object
#  19  R-02-01-21        57 non-null     int64
#  20  01-01-21          56 non-null     object
#  21  R-01-01-21        57 non-null     int64
# dtypes: int64(11), object(11)
# memory usage: 9.9+ KB

# %%
#To know null values
df_cls1.isna().sum()
# Out:
# Student Roll Num     0
# Type                25
# 10-01-21             0
# R-10-01-21           0
# 09-01-21             0
# R-9-01-21            0
# 08-01-21             0
# R-8-01-21            0
# 07-01-21             1
# R-7-01-21            0
# 06-01-21             1
# R-6-01-21            0
# 05-01-21             1
# R-5-01-21            0
# 04-01-21             1
# R-4-01-21            0
# 03-01-21             1
# R-3-01-21            0
# 02-01-21             1
# R-02-01-21           0
# 01-01-21             1
# R-01-01-21           0
# dtype: int64

# %%
#Imputing NULL values
df1_fill = df_cls1["07-01-21"].mode()[0]
df_cls1["07-01-21"] = df_cls1["07-01-21"].fillna(df1_fill)

# %%
df2_fill = df_cls1["06-01-21"].mode()[0]
df_cls1["06-01-21"] = df_cls1["06-01-21"].fillna(df2_fill)

# %%
df3_fill = df_cls1["05-01-21"].mode()[0]
df_cls1["05-01-21"] = df_cls1["05-01-21"].fillna(df3_fill)

# %%
df4_fill = df_cls1["04-01-21"].mode()[0]
df_cls1["04-01-21"] = df_cls1["04-01-21"].fillna(df4_fill)

# %%
df5_fill = df_cls1["03-01-21"].mode()[0]
df_cls1["03-01-21"] = df_cls1["03-01-21"].fillna(df5_fill)

# %%
df6_fill = df_cls1["02-01-21"].mode()[0]
df_cls1["02-01-21"] = df_cls1["02-01-21"].fillna(df6_fill)

# %%
df7_fill = df_cls1["01-01-21"].mode()[0]
df_cls1["01-01-21"] = df_cls1["01-01-21"].fillna(df7_fill)

# %%
#To check if any null values are still present
df_cls1.isna().sum()
# Out:
# Student Roll Num     0
# Type                25
# 10-01-21             0
# R-10-01-21           0
# 09-01-21             0
# R-9-01-21            0
# 08-01-21             0
# R-8-01-21            0
# 07-01-21             0
# R-7-01-21            0
# 06-01-21             0
# R-6-01-21            0
# 05-01-21             0
# R-5-01-21            0
# 04-01-21             0
# R-4-01-21            0
# 03-01-21             0
# R-3-01-21            0
# 02-01-21             0
# R-02-01-21           0
# 01-01-21             0
# R-01-01-21           0
# dtype: int64

# %%
#Analysis on "TYPE" column
df_cls1["Type"]
# Out:
# 0     WORKING
# 1         NaN
# 2     STUDENT
# 3     STUDENT
# 4     WORKING
# 5         NaN
# 6     STUDENT
# 7     STUDENT
# 8      IGNORE
# 9         NaN
# 10    STUDENT
# 11    STUDENT
# 12    STUDENT
# 13    STUDENT
# 14    WORKING
# 15    WORKING
# 16    STUDENT
# 17        NaN
# 18        NaN
# 19        NaN
# 20        NaN
# 21    WORKING
# 22        NaN
# 23    WORKING
# 24    STUDENT
# 25    STUDENT
# 26        NaN
# 27    STUDENT
# 28    STUDENT
# 29    WORKING
# 30        NaN
# 31    STUDENT
# 32    STUDENT
# 33    STUDENT
# 34    STUDENT
# 35    WORKING
# 36        NaN
# 37        NaN
# 38        NaN
# 39        NaN
# 40        NaN
# 41        NaN
# 42        NaN
# 43        NaN
# 44        NaN
# 45    STUDENT
# 46        NaN
# 47        NaN
# 48    STUDENT
# 49     IGNORE
# 50    STUDENT
# 51    DROPOUT
# 52        NaN
# 53        NaN
# 54    WORKING
# 55        NaN
# 56        NaN
# Name: Type, dtype: object

# %%
#Imputing "TYPE" column
df_fill = df_cls1["Type"].mode()[0]
df_cls1["Type"] = df_cls1["Type"].fillna(df_fill)

# %%
df_cls1.head()
# Out:
#    Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21  \
# 0                 1  WORKING   Missed           9   Missed         10
# 1                 2  STUDENT   Missed           8   Missed          6
# 2                 3  STUDENT   Missed           5   Missed          5
# 3                 4  STUDENT   Missed           6   Missed          6
# 4                 5  WORKING   Missed           6   Missed          7
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ...  05-01-21  R-5-01-21  \
# 0    Missed          8    Missed          5  ...    Missed          8
# 1    Missed          9  Attended          9  ...  Attended          7
# 2    Missed          8    Missed          9  ...  Attended          6
# 3  Attended          8    Missed          6  ...    Missed          6
# 4    Missed          9    Missed          6  ...    Missed          6
#
#    04-01-21  R-4-01-21  03-01-21  R-3-01-21  02-01-21  R-02-01-21  01-01-21  \
# 0    Missed          9    Missed          8    Missed           6    Missed
# 1  Attended          7    Missed          8  Attended           7    Missed
# 2    Missed          6    Missed          8  Attended          10  Attended
# 3  Attended          8  Attended          7  Attended           5  Attended
# 4    Missed         10    Missed         10    Missed           8    Missed
#
#    R-01-01-21
# 0           8
# 1           8
# 2          10
# 3           6
# 4           7
#
# [5 rows x 22 columns]

# %%
#EDA on Class2

# %%
df_cls2.head()
# Out:
#    Student Roll Num     Type  10-01-21  R-10-01-21  09-01-21  R-9-01-21  \
# 0                 1      NaN  Attended           5  Attended          5
# 1                 2      NaN  Attended           9  Attended          9
# 2                 3  STUDENT    Missed           5    Missed          6
# 3                 4      NaN  Attended           7  Attended          6
# 4                 5  WORKING  Attended           5  Attended          5
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  06-01-21  R-6-01-21  05-01-21  \
# 0  Attended         10  Attended          9  Attended         10  Attended
# 1  Attended         10  Attended          9  Attended          7  Attended
# 2    Missed          6    Missed          5    Missed          5    Missed
# 3  Attended         10  Attended          9    Missed          9    Missed
# 4  Attended          6    Missed          9    Missed          5    Missed
#
#    R-5-01-21  04-01-21  R-4-01-21  03-01-21  R-3-01-21  01-01-21  R-01-01-21
# 0          5  Attended          8    Missed          9       NaN         NaN
# 1          6  Attended          5  Attended          8       NaN         NaN
# 2         10    Missed          9    Missed          8       NaN         NaN
# 3          7  Attended         10  Attended          5       NaN         NaN
# 4         10    Missed          9    Missed          6       NaN         NaN

# %%
df_cls2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Student Roll Num  70 non-null     int64
#  1   Type              30 non-null     object
#  2   10-01-21          70 non-null     object
#  3   R-10-01-21        70 non-null     int64
#  4   09-01-21          70 non-null     object
#  5   R-9-01-21         70 non-null     int64
#  6   08-01-21          70 non-null     object
#  7   R-8-01-21         70 non-null     int64
#  8   07-01-21          69 non-null     object
#  9   R-7-01-21         70 non-null     int64
#  10  06-01-21          69 non-null     object
#  11  R-6-01-21         70 non-null     int64
#  12  05-01-21          69 non-null     object
#  13  R-5-01-21         70 non-null     int64
#  14  04-01-21          69 non-null     object
#  15  R-4-01-21         70 non-null     int64
#  16  03-01-21          67 non-null     object
#  17  R-3-01-21         70 non-null     int64
#  18  01-01-21          0 non-null      float64
#  19  R-01-01-21        0 non-null      float64
# dtypes: float64(2), int64(9), object(9)
# memory usage: 11.1+ KB

# %%
df_cls2.isna().sum()
# Out:
# Student Roll Num     0
# Type                40
# 10-01-21             0
# R-10-01-21           0
# 09-01-21             0
# R-9-01-21            0
# 08-01-21             0
# R-8-01-21            0
# 07-01-21             1
# R-7-01-21            0
# 06-01-21             1
# R-6-01-21            0
# 05-01-21             1
# R-5-01-21            0
# 04-01-21             1
# R-4-01-21            0
# 03-01-21             3
# R-3-01-21            0
# 01-01-21            70
# R-01-01-21          70
# dtype: int64

# %%
df2_fill1 = df_cls2["07-01-21"].mode()[0]
df_cls2["07-01-21"] = df_cls2["07-01-21"].fillna(df2_fill1)

# %%
df2_fill2 = df_cls2["06-01-21"].mode()[0]
df_cls2["06-01-21"] = df_cls2["06-01-21"].fillna(df2_fill2)

# %%
df2_fill3 = df_cls2["05-01-21"].mode()[0]
df_cls2["05-01-21"] = df_cls2["05-01-21"].fillna(df2_fill3)

# %%
df2_fill4 = df_cls2["04-01-21"].mode()[0]
df_cls2["04-01-21"] = df_cls2["04-01-21"].fillna(df2_fill4)

# %%
df2_fill5 = df_cls2["03-01-21"].mode()[0]
df_cls2["03-01-21"] = df_cls2["03-01-21"].fillna(df2_fill5)

# %%
df_cls2.isna().sum()
# Out:
# Student Roll Num     0
# Type                40
# 10-01-21             0
# R-10-01-21           0
# 09-01-21             0
# R-9-01-21            0
# 08-01-21             0
# R-8-01-21            0
# 07-01-21             0
# R-7-01-21            0
# 06-01-21             0
# R-6-01-21            0
# 05-01-21             0
# R-5-01-21            0
# 04-01-21             0
# R-4-01-21            0
# 03-01-21             0
# R-3-01-21            0
# 01-01-21            70
# R-01-01-21          70
# dtype: int64

# %%
df_cls2.shape
# Out:
# (70, 20)

# %%
fil2 = df_cls2["Type"].mode()[0]
df_cls2["Type"] = df_cls2["Type"].fillna(fil2)

# %%
df_cls2.isna().sum()
# Out:
# Student Roll Num     0
# Type                 0
# 10-01-21             0
# R-10-01-21           0
# 09-01-21             0
# R-9-01-21            0
# 08-01-21             0
# R-8-01-21            0
# 07-01-21             0
# R-7-01-21            0
# 06-01-21             0
# R-6-01-21            0
# 05-01-21             0
# R-5-01-21            0
# 04-01-21             0
# R-4-01-21            0
# 03-01-21             0
# R-3-01-21            0
# 01-01-21            70
# R-01-01-21          70
# dtype: int64

# %%
#CONCATING both classes

# %%
df = pd.concat([df_cls1, df_cls2])

# %%
df.shape
# Out:
# (127, 22)

# %%
df.fillna(0,inplace=True)

# %%
df.isna().sum()
# Out:
# Student Roll Num    0
# Type                0
# 10-01-21            0
# R-10-01-21          0
# 09-01-21            0
# R-9-01-21           0
# 08-01-21            0
# R-8-01-21           0
# 07-01-21            0
# R-7-01-21           0
# 06-01-21            0
# R-6-01-21           0
# 05-01-21            0
# R-5-01-21           0
# 04-01-21            0
# R-4-01-21           0
# 03-01-21            0
# R-3-01-21           0
# 02-01-21            0
# R-02-01-21          0
# 01-01-21            0
# R-01-01-21          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Student Roll Num', 'Type', '10-01-21', 'R-10-01-21', '09-01-21',
#        'R-9-01-21', '08-01-21', 'R-8-01-21', '07-01-21', 'R-7-01-21',
#        '06-01-21', 'R-6-01-21', '05-01-21', 'R-5-01-21', '04-01-21',
#        'R-4-01-21', '03-01-21', 'R-3-01-21', '02-01-21', 'R-02-01-21',
#        '01-01-21', 'R-01-01-21'],
#       dtype='object')

# %%
df['Attended_Count'] = df[df == 'Attended'].count(axis=1)
df['Missed_Count'] = df[df == 'Missed'].count(axis=1)

# Calculating the total sessions for each type
df['Total_Sessions'] = df[['Attended_Count', 'Missed_Count']].sum(axis=1)

# Calculating the attendance percentage and missed percentage for each type
df['Attended_Percentage'] = (df['Attended_Count'] / df['Total_Sessions']) * 100
df['Missed_Percentage'] = (df['Missed_Count'] / df['Total_Sessions']) * 100

# %%
df.head()
# Out:
#    Student Roll Num     Type 10-01-21  R-10-01-21 09-01-21  R-9-01-21  \
# 0                 1  WORKING   Missed           9   Missed         10
# 1                 2  STUDENT   Missed           8   Missed          6
# 2                 3  STUDENT   Missed           5   Missed          5
# 3                 4  STUDENT   Missed           6   Missed          6
# 4                 5  WORKING   Missed           6   Missed          7
#
#    08-01-21  R-8-01-21  07-01-21  R-7-01-21  ... R-3-01-21  02-01-21  \
# 0    Missed          8    Missed          5  ...         8    Missed
# 1    Missed          9  Attended          9  ...         8  Attended
# 2    Missed          8    Missed          9  ...         8  Attended
# 3  Attended          8    Missed          6  ...         7  Attended
# 4    Missed          9    Missed          6  ...        10    Missed
#
#   R-02-01-21  01-01-21 R-01-01-21  Attended_Count Missed_Count  \
# 0        6.0    Missed        8.0               0           10
# 1        7.0    Missed        8.0               4            6
# 2       10.0  Attended       10.0               4            6
# 3        5.0  Attended        6.0               5            5
# 4        8.0    Missed        7.0               0           10
#
#    Total_Sessions Attended_Percentage  Missed_Percentage
# 0              10                 0.0              100.0
# 1              10                40.0               60.0
# 2              10                40.0               60.0
# 3              10                50.0               50.0
# 4              10                 0.0              100.0
#
# [5 rows x 27 columns]

# %%
student_data = df[df['Type'] == 'STUDENT']
working_data = df[df['Type'] == 'WORKING']
ignore_data = df[df['Type'] == 'IGNORE']
dropout_data = df[df['Type'] == 'DROPOUT']

# Preparing data for plotting
types = ['Student', 'Working', 'IGNORE', 'Dropout']
attended_percentage = [
    student_data['Attended_Percentage'].mean(),
    working_data['Attended_Percentage'].mean(),
    ignore_data['Attended_Percentage'].mean(),
    dropout_data['Attended_Percentage'].mean()
]

missed_percentage = [
    student_data['Missed_Percentage'].mean(),
    working_data['Missed_Percentage'].mean(),
    ignore_data['Missed_Percentage'].mean(),
    dropout_data['Missed_Percentage'].mean()
]

# Setting the width of each bar
bar_width = 0.3

# Setting the positions of the bars on the x-axis
r1 = range(len(types))
r2 = [x + bar_width for x in r1]

# %%
# Creating bar plot
plt.figure(figsize=(15, 6))
plt.bar(r1, attended_percentage, color='#33FF99', width=bar_width, edgecolor='white', label='Attended')
plt.bar(r2, missed_percentage, color='#FF6666', width=bar_width, edgecolor='white', label='Missed')

# Adding labels 
plt.xlabel('Type')
plt.ylabel('Percentage')
plt.title('Attendance Percentage by Type')
plt.xticks([r + bar_width/2 for r in range(len(types))], types)
plt.legend()
plt.show()

# %% [markdown]
# # 1. From the above bar plot we can clearly observe that most classes are attended by student and working
# # 2. Ignore and dropouts are not attending the classes
# # 3. Students are almost equally attending and missing the classes

# %%
student_ratings = df[df['Type'] == 'STUDENT'][['R-10-01-21', 'R-9-01-21', 'R-8-01-21', 'R-7-01-21', 'R-6-01-21', 'R-5-01-21', 'R-4-01-21', 'R-3-01-21', 'R-02-01-21', 'R-01-01-21']]
working_ratings = df[df['Type'] == 'WORKING'][['R-10-01-21', 'R-9-01-21', 'R-8-01-21', 'R-7-01-21', 'R-6-01-21', 'R-5-01-21', 'R-4-01-21', 'R-3-01-21', 'R-02-01-21', 'R-01-01-21']]
ignore_ratings = df[df['Type'] == 'IGNORE'][['R-10-01-21', 'R-9-01-21', 'R-8-01-21', 'R-7-01-21', 'R-6-01-21', 'R-5-01-21', 'R-4-01-21', 'R-3-01-21', 'R-02-01-21', 'R-01-01-21']]
dropout_ratings = df[df['Type'] == 'DROPOUT'][['R-10-01-21', 'R-9-01-21', 'R-8-01-21', 'R-7-01-21', 'R-6-01-21', 'R-5-01-21', 'R-4-01-21', 'R-3-01-21', 'R-02-01-21', 'R-01-01-21']]

student_ratings = student_ratings.values.flatten()
working_ratings = working_ratings.values.flatten()
ignore_ratings = ignore_ratings.values.flatten()
dropout_ratings = dropout_ratings.values.flatten()

ratings = np.concatenate([student_ratings, working_ratings, ignore_ratings, dropout_ratings])
types = ['STUDENT'] * len(student_ratings) + ['WORKING'] * len(working_ratings) + ['IGNORE'] * len(ignore_ratings) + ['DROPOUT'] * len(dropout_ratings)
df_ratings = pd.DataFrame({'Rating': ratings, 'Type': types})

# Filtering ratings within the range of 5-7
filtered_ratings = df_ratings[(df_ratings['Rating'] >= 5) & (df_ratings['Rating'] <= 7)]

# Counting the occurrence of each rating for each type
rating_counts = filtered_ratings.groupby(['Type', 'Rating']).size().reset_index(name='Count')

# %%
# Plotting the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Type', y='Count', hue='Rating', data=rating_counts, palette='pastel')

plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Count of Ratings (5-7) by Type')

plt.legend(title='Rating')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 1. From the above plot we can observe that least ratings were given by working people followed by student
# # 2. In the previous plot we have seen that dropout and ignore are having less attendance so they have given less ratings

# %%
# Concatenating the ratings and creating a new dataframe
ratings = np.concatenate([student_ratings, working_ratings, ignore_ratings, dropout_ratings])
types = ['STUDENT'] * len(student_ratings) + ['WORKING'] * len(working_ratings) + ['IGNORE'] * len(ignore_ratings) + ['DROPOUT'] * len(dropout_ratings)
df_ratings = pd.DataFrame({'Rating': ratings, 'Type': types})

# Filtering the ratings within the range of 5-7
filtered_ratings = df_ratings[(df_ratings['Rating'] >= 8) & (df_ratings['Rating'] <= 10)]

# Counting the occurrences of each rating for each type
rating_counts = filtered_ratings.groupby(['Type', 'Rating']).size().reset_index(name='Count')

# %%
# Plot the multiple bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Type', y='Count', hue='Rating', data=rating_counts)

plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Count of Ratings (8-10) by Type')

plt.legend(title='Rating')
plt.tight_layout()
plt.show()

# %% [markdown]
# # From the above plot we can observe that highest ratings were given Student    and working.
# # We can declare that Student and Working are most statisfied, hence the gave   more Ratings

# %%
student_ratings = df_cls1[df_cls1['Type'] == 'STUDENT'][['R-10-01-21', 'R-9-01-21', 'R-8-01-21', 'R-7-01-21', 'R-6-01-21', 'R-5-01-21', 'R-4-01-21', 'R-3-01-21', 'R-02-01-21', 'R-01-01-21']]
working_ratings = df_cls1[df_cls1['Type'] == 'WORKING'][['R-10-01-21', 'R-9-01-21', 'R-8-01-21', 'R-7-01-21', 'R-6-01-21', 'R-5-01-21', 'R-4-01-21', 'R-3-01-21', 'R-02-01-21', 'R-01-01-21']]
ignore_ratings = df_cls1[df_cls1['Type'] == 'IGNORE'][['R-10-01-21', 'R-9-01-21', 'R-8-01-21', 'R-7-01-21', 'R-6-01-21', 'R-5-01-21', 'R-4-01-21', 'R-3-01-21', 'R-02-01-21', 'R-01-01-21']]
dropout_ratings = df_cls1[df_cls1['Type'] == 'DROPOUT'][['R-10-01-21', 'R-9-01-21', 'R-8-01-21', 'R-7-01-21', 'R-6-01-21', 'R-5-01-21', 'R-4-01-21', 'R-3-01-21', 'R-02-01-21', 'R-01-01-21']]

student_ratings = student_ratings.values.flatten()
working_ratings = working_ratings.values.flatten()
ignore_ratings = ignore_ratings.values.flatten()
dropout_ratings = dropout_ratings.values.flatten()

ratings = np.concatenate([student_ratings, working_ratings, ignore_ratings, dropout_ratings])
types = ['STUDENT'] * len(student_ratings) + ['WORKING'] * len(working_ratings) + ['IGNORE'] * len(ignore_ratings) + ['DROPOUT'] * len(dropout_ratings)
df_ratings = pd.DataFrame({'Rating': ratings, 'Type': types})

# Filter the ratings within the range of 5-7
filtered_ratings = df_ratings[(df_ratings['Rating'] >= 5) & (df_ratings['Rating'] <= 10)]

# Count the occurrences of each rating for each type
rating_counts = filtered_ratings.groupby(['Type', 'Rating']).size().reset_index(name='Count')

# %%
# Plotting the bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Type', y='Count', hue='Rating', data=rating_counts, palette='dark')

plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Count of Ratings (5-10) by Type')

plt.legend(title='Rating')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 1. From the above plot the highest ratings given by students followed by working
# # 2. As usually the dropout and ignored have given very low ratings
# # 3. We can easily say that ignored and dropout students are least satisfied

# %%
# Calculating the attendance count and missed count for both type
df_cls1['Attended_Count'] = df_cls1[df_cls1 == 'Attended'].count(axis=1)
df_cls1['Missed_Count'] = df_cls1[df_cls1 == 'Missed'].count(axis=1)

# Calculating the total sessions for each type
df_cls1['Total_Sessions'] = df_cls1[['Attended_Count', 'Missed_Count']].sum(axis=1)

# Calculate the attendance percentage and missed percentage for each type
df_cls1['Attended_Percentage'] = (df_cls1['Attended_Count'] / df_cls1['Total_Sessions']) * 100
df_cls1['Missed_Percentage'] = (df_cls1['Missed_Count'] / df_cls1['Total_Sessions']) * 100

student_data = df_cls1[df_cls1['Type'] == 'STUDENT']
working_data = df_cls1[df_cls1['Type'] == 'WORKING']
ignore_data = df_cls1[df_cls1['Type'] == 'IGNORE']
dropout_data = df_cls1[df_cls1['Type'] == 'DROPOUT']

# Preparing data for plotting
types = ['Student', 'Working', 'IGNORE', 'Dropout']
attended_percentage = [
    student_data['Attended_Percentage'].mean(),
    working_data['Attended_Percentage'].mean(),
    ignore_data['Attended_Percentage'].mean(),
    dropout_data['Attended_Percentage'].mean()
]

missed_percentage = [
    student_data['Missed_Percentage'].mean(),
    working_data['Missed_Percentage'].mean(),
    ignore_data['Missed_Percentage'].mean(),
    dropout_data['Missed_Percentage'].mean()
]

# Setting width of each bar
bar_width = 0.3

# Setting positions of the bars on x-axis
r1 = range(len(types))
r2 = [x + bar_width for x in r1]

# Creating bar plot
plt.figure(figsize=(15, 6))
plt.bar(r1, attended_percentage, color='#33FF99', width=bar_width, edgecolor='white', label='Attended')
plt.bar(r2, missed_percentage, color='#FF6666', width=bar_width, edgecolor='white', label='Missed')

# Adding labels
plt.xlabel('Type')
plt.ylabel('Percentage')
plt.title('Attendance Percentage by Type')
plt.xticks([r + bar_width/2 for r in range(len(types))], types)
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# # 1. From the above plot classes are attended most by students followed by working
# # 2. Attendance was completely ignored by dropouts and ignored

# %%
# Calculate the attendance count and missed count for each type
df_cls2['Attended_Count'] = df_cls2[df_cls2 == 'Attended'].count(axis=1)
df_cls2['Missed_Count'] = df_cls2[df_cls2 == 'Missed'].count(axis=1)

# Calculate the total sessions for each type
df_cls2['Total_Sessions'] = df_cls2[['Attended_Count', 'Missed_Count']].sum(axis=1)

# Calculate the attendance percentage and missed percentage for each type
df_cls2['Attended_Percentage'] = (df_cls2['Attended_Count'] / df_cls2['Total_Sessions']) * 100
df_cls2['Missed_Percentage'] = (df_cls2['Missed_Count'] / df_cls2['Total_Sessions']) * 100

student_data = df_cls2[df_cls2['Type'] == 'STUDENT']
working_data = df_cls2[df_cls2['Type'] == 'WORKING']
ignore_data = df_cls2[df_cls2['Type'] == 'IGNORE']
dropout_data = df_cls2[df_cls2['Type'] == 'DROPOUT']

# Prepare data for plotting
types = ['Student', 'Working', 'IGNORE', 'Dropout']
attended_percentage = [
    student_data['Attended_Percentage'].mean(),
    working_data['Attended_Percentage'].mean(),
    ignore_data['Attended_Percentage'].mean(),
    dropout_data['Attended_Percentage'].mean()
]

missed_percentage = [
    student_data['Missed_Percentage'].mean(),
    working_data['Missed_Percentage'].mean(),
    ignore_data['Missed_Percentage'].mean(),
    dropout_data['Missed_Percentage'].mean()
]

# Set the width of each bar
bar_width = 0.3

# Set the positions of the bars on the x-axis
r1 = range(len(types))
r2 = [x + bar_width for x in r1]

# Create the bar plot
plt.figure(figsize=(15, 6))
plt.bar(r1, attended_percentage, color='#33FF99', width=bar_width, edgecolor='white', label='Attended')
plt.bar(r2, missed_percentage, color='#FF6666', width=bar_width, edgecolor='white', label='Missed')

# Add labels, title, and legend
plt.xlabel('Type')
plt.ylabel('Percentage')
plt.title('Attendance Percentage by Type')
plt.xticks([r + bar_width/2 for r in range(len(types))], types)
plt.legend()
# Show the plot
plt.show()

# %% [markdown]
# # 1. In class 2 there is a fall of attendance by students
# # 2. As usually the attendance was neglected by deopouts and ignored

# %%
#CONCLUSION

# Here both Students and Working needs attention for missing sessions
# We can easily say that ignored and dropout students are least satisfied
# Students and working are more satisfied
